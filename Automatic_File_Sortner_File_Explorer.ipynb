# %% [markdown]
# # Automatic File Sortner in File explorer

# %%
import os,shutil

# %%
path= r"E:/MySQL_Alex_Boot_Camp/Python Tut Project_02/" # r to take the path as whole string raw  irrespective of /

# %%
# we will check i there is an folder already present for each file type if not we will create the req folders and then enter the repsective .txt .csv .png 
# into their respective folders 
# Hence this project provides some real life applications to begin with

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'BMI_CALC.ipynb', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
os.listdir(path)
# Out:
# ['dosti.txt',
#  'leetcode_200_badge.png',
#  'olist_customers_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv']

# %%
os.path.exists(path + 'csv files')
# Out:
# False

# %%
folder_names=['csv files','image files','text files']
for loop in range(0,3):
    if not os.path.exists(path + folder_names[loop]):
        print(path + folder_names[loop])
        os.makedirs(path + folder_names[loop])
# Out:
# E:/MySQL_Alex_Boot_Camp/Python Tut Project_02/csv files
# E:/MySQL_Alex_Boot_Camp/Python Tut Project_02/image files
# E:/MySQL_Alex_Boot_Camp/Python Tut Project_02/text files

# %%
# now will write the script which will read the documents image png and csv then place it in their resp file folders just created
# os.listdir(path) we will loop through this to check it place in their correct folders

# %%
file_name = os.listdir(path) 

for file in file_name:
    if ".csv" in file and not os.path.exists(path + "csv files/" + file):
        shutil.move(path + file, path + "csv files/" + file)
    elif ".png" in file and not os.path.exists(path + "image files/" + file):
        shutil.move(path + file, path + "image files/" + file)
    if ".txt" in file and not os.path.exists(path + "text files/" + file):
        shutil.move(path + file, path + "text files/" + file)
